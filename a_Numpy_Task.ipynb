# %% [markdown]
# ### ndarray Task

# %%
import numpy as np
# 1~10까지의 요소를 ndarray에 담기
ndarray = np.array([i for i in range(1, 11)])
print(ndarray)
# 3행 2열 list를 ndarray에 담고 각 요소는 순서대로 6, 5, 4, 3, 2, 1을 담는다.
ndarray32 = np.array([[6,5],[4,3],[2,1]])
print(ndarray32)
# 4행 1열 ndarray, 요소는 순서대로 10, 8, 6, 4를 담는다.(transpose, 전치)
ndarray41 = np.array([[10], [8], [6], [4]])
print(ndarray41)
#1에서 제작된 ndarray의 요소 타입 출력
print(type(ndarray))
#1에서 제작된 ndarray의 차원 출력
print(ndarray.shape)
print('2번문제')
#2에서 제작된 ndarray의 요소 타입을 float으로 변환
ndarray32_flo = ndarray32.astype(float)
#2에서 제작된 ndarray의 차원 출력
print(ndarray32.shape)
print('3번문제')
#3에서 제작된 ndarray의 요소 타입을 int8로 변환
ndarray41_int8 = ndarray41.astype('int8')
#3에서 제작된 Ndarray의 요소에 5씩 더하기
print(ndarray41_int8 + 5)
#3에서 제작된 ndarray의 차원 출력
print(ndarray41.shape)


# 4행 1열 transpose 풀이
ndarray123 = np.array([[(5 - i) * (for i in range(4))]]).T
print(ndarray123)


# import numpy as np

# #1 1~10까지의 요소를 ndarray에 담는다.
# # ndarray1 = np.array([i for i in range(1, 11)])
# ndarray1 = np.array(list(range(1, 11)))
# print(type(ndarray1), ndarray1.shape, ndarray1.ndim, ndarray1.dtype, sep="\n")

# print("=" * 50)

# #2 3행 2열 list를 ndarray에 담고 각 요소는 순서대로 6, 5, 4, 3, 2, 1을 담는다.
# python_list = []
# python_list.append([6 - i for i in range(2)])
# python_list.append([4 - i for i in range(2)])
# python_list.append([2 - i for i in range(2)])

# ndarray2 = np.array(python_list)
# print(type(ndarray2), ndarray2.shape, ndarray2.ndim, ndarray2.dtype, sep="\n")

# print("=" * 50)

# #3 4행 1열 ndarray, 순서대로 10, 8, 6, 4를 담는다(transpose, 전치).
# ndarray3 = np.array([[(5 - i) * 2 for i in range(4)]]).T
# print(type(ndarray3), ndarray3.shape, ndarray3.ndim, ndarray3.dtype, sep="\n")

# print("=" * 50)

# # #1에서 제작된 ndarray의 요소 타입 출력
# print(ndarray1.dtype)

# print("=" * 50)

# # #1에서 제작된 ndarray의 차원 출력
# print(ndarray1.shape)

# print("=" * 50)

# # #2에서 제작된 ndarray의 요소 타입을 float으로 변환
# ndarray2_float32 = ndarray2.astype(np.float32)
# print(ndarray2_float32)

# print("=" * 50)

# # #2에서 제작된 ndarray의 차원 출력
# print(ndarray2.shape)

# print("=" * 50)

# # #3에서 제작된 ndarray의 요소 타입을 int8로 변환
# ndarray2_int8 = ndarray2.astype(np.int8)
# print(ndarray2_int8.dtype, ndarray2_int8, sep="\n")

# print("=" * 50)

# # #3에서 제작된 ndarray의 요소에 5씩 더하기
# ndarray3_result = ndarray3 + 5
# print(ndarray3_result)

# print("=" * 50)

# # #3에서 제작된 ndarray의 차원 출력
# print(ndarray3.shape)

# %% [markdown]
# ### arange, zeros, ones Task

# %%
# axis0이 10인 shape이면서 모든 원소가 0, dtype은 int32 인 ndarray 만들기
ndarray = np.zeros((10,))
ndarray_int8 = ndarray.astype(np.int32)
print(ndarray_int8)
# axis0이 3, axis1이 4인 shape이면서 모든 원소가 1인 ndarray 만들기
ndarray3 = np.ones((3,4))
print(ndarray3)
# axis0이 5, 각 요소가 0~4인 ndarray 만들기
ndarray5 = np.arange(0, 5)
print(ndarray5)

like_array = np.array([1, 2, 3])
new_array = np.arange(1, 4, like=like_array)


# import numpy as np

# # axis 0이 10인 shape이면서 모든 원소가 0, dtype은 int32 인 ndarray 만들기
# ndarray = np.zeros((10, ), dtype=np.int32)
# print(ndarray, ndarray.dtype, ndarray.shape)

# # axis 0이 3, axis1이 4인 shape이면서 모든 원소가 1인 ndarray 만들기
# ndarray = np.ones((3, 4), dtype=np.int8)
# print(ndarray, ndarray.dtype, ndarray.shape)

# # axis 0이 5, 각 요소가 0~4인 ndarray 만들기
# ndarray = np.arange(5)
# print(ndarray, ndarray.dtype, ndarray.shape)

# %% [markdown]
# ### reshape Task

# %%
ndarray1 = np.arange(start=0, stop=16)
ndarray1

print("=" * 50)

# 2 Dimension, axis 1은 2로 변경
ndarray2 = ndarray1.reshape((-1, 2))
print(ndarray2.shape, ndarray2, sep="\n")

print("=" * 50)

# 2 Dimension, axis 0은 8로 변경
ndarray3 = ndarray1.reshape((8, -1))
print(ndarray3.shape, ndarray3, sep="\n")

print("=" * 50)

# 3 Dimension으로 변경
ndarray4 = ndarray1.reshape((4, 2, -1))
print(ndarray4.shape, ndarray4, sep="\n")

print("=" * 50)

# ndarray3을 axis 1이 1인 2차원 ndarray로 변환
ndarray5 = ndarray4.reshape((-1, 1))
print(ndarray5.shape, ndarray5, sep="\n")

print("=" * 50)

# ndarray3을 1 Dimension으로 변환
ndarray6 = ndarray4.reshape((-1,))
print(ndarray6.shape, ndarray6, sep="\n")

# %% [markdown]
# ### Indexing Task

# %%
# 1-1. 1차원 위치 인덱싱
ndarray = np.arange(start=2, stop=22)
print(ndarray)

data = ndarray[7]
print(data)

data = ndarray[-11] 
print(data) 

ndarray[-11] = 40  
print(ndarray)

# %%
# 1-2. 2차원 위치 인덱싱
ndarray = np.arange(start=2, stop=22)
ndarray1 = ndarray.reshape((4, -1))
print(ndarray1)

print(ndarray1[0, 1])
print(ndarray1[1, 4])
print(ndarray1[2, 2])


ndarray1[2, 4] = 200
print(ndarray1)  


print(ndarray1[2], ndarray1[2].shape)

# %%
# 2-1. 1차원 슬라이싱
ndarray = np.arange(start=3, stop=300, step=7)
print(ndarray)
print(ndarray[1:20:2])
print(ndarray[20::3])
print(ndarray[-30::4])
print(ndarray[::-15])

# %%
# 2-2. 2차원 슬라이싱
ndarray = np.arange(start=2, stop=102)
ndarray1 = ndarray.reshape((-1, 4))
print(ndarray1)


print(ndarray1[:8, :2])


print(ndarray1[3:7])


print(ndarray1[-1::-1, 3:6])


print(ndarray1[::-1])


print(ndarray1[::-1, ::-1])

# %%
# 3. 팬시 인덱싱(Fancy indexing)
ndarray = np.arange(start=2, stop=74)
ndarray1 = ndarray.reshape(9, -1)
print(ndarray1)

print(ndarray1[[0, 3, 7, 8], 0:4])
print(ndarray1[[0, 8]])
print(ndarray1[[0, 2, 5, 7], [0, 2, 3, 5]])

# %%
# 4. 불린 인덱싱
ndarray = np.arange(start=2, stop=60)
print(ndarray % 3 == 0)
print(ndarray[ndarray % 3 == 0])
print((ndarray % 3 == 0) & (ndarray % 7 == 0))
print(ndarray[(ndarray % 3 == 0) & (ndarray % 7 == 0)])

ndarray1 = np.arange(start=2, stop=12)
print(ndarray1)

# %%
########정리한 Task#########
import numpy as np

# 1. 위치 인덱싱(Location indexing)
# 1-1. 1차원 배열 1~100값 중 97값 추출하기
ndarray1 = np.arange(1, 101)
print(ndarray1[-4])

print("=" * 50)

# 1-2. 1~30까지의 요소를 ndarray에 담는다.
ndarray1 = np.arange(start=1, stop=31)
print(ndarray1)

print('=' * 50)

# 2. 2차원 위치 인덱싱(Location indexing)
# 2-1. 2차원 배열 axis 0은 4, axis 1은 5로 1~20 요소 중 15값 추출하기
ndarray1 = np.arange(1, 21)
ndarray2 = ndarray1.reshape((4,5))
print(ndarray2[2, 4])

print("=" * 50)

# 2-2. Dimension, axis 0은 5로 변경
ndarray2 = ndarray1.reshape((5, -1))
print(ndarray2)

print("=" * 50)

# 2-3. 2행의 4번째 숫자 출력 (Location indexing)
print(ndarray2[1,3])

print("=" * 50)

# 3. 불린 인덱싱 (Boolean indexing)
# 3-1. 1~100중 짝수만 출력
ndarray1 = np.arange(1, 101)
ndarray2 = ndarray1[ndarray1 % 2 == 0]
print(ndarray2)

print("=" * 50)

# 3-2. 3-1에서 구한 요소를 axis 0이 10인 2차원 배열로 변환 후 82~100까지 추출하기
ndarray2 = ndarray1.reshape((10, -1))
ndarray3 = ndarray2[8:]
print(ndarray3.flatten())

print("=" * 50)

# 3-3. 3-2에서 구한 요소 중 x:86 y:100 좌표 구하기
ndarray4 = ndarray3[[0, 1],[2, 4]] 
print(ndarray4)

print("=" * 50)

# 3-4. 불리언 인덱싱을 사용하여 각 요소중 1의 자리가 2인 수들만 추출하시오
ndarray1 = np.arange(1, 101)
ndarray2 = ndarray1[ndarray1 % 2 == 0]
cond = ndarray2 % 10 == 2
ndarray3 = ndarray2[cond]

print(ndarray3)

print("=" * 50)

# 3-5. 1~49 요소 중 2와 5의 공배수를 추출하세요.
ndarray1 = np.arange(start=1, stop=50)

cond1 = ndarray % 2 == 0
cond2 = ndarray % 5 == 0
cond3 = cond1 & cond2

ndarray2 = ndarray[cond3]
print(ndarray2)

print("=" * 50)

# 3-6. 3-5에서 추출한 공배수 중 20이상인 값만 추출하세요.
print(ndarray2[(ndarray2 >= 20)])

# %% [markdown]
# ### Like Test

# %%
np.array([1, 2, 3])
np.arange(1, 4)
liarray = np.array([1, 2, 3])
new_array = np.arange(1, 4, like = liarray)
print(new_array)
# 무슨 기능인지 잘 모르겠음

# %% [markdown]
# ### alone task

# %%
import numpy as np

# 1. 위치 인덱싱(Location indexing)
# 1-1. 1차원 배열 1~100값 중 97값 추출하기
ndarray1 = np.arange(1, 101)
print(ndarray1[-4])

print("=" * 50)

# 1-2. 1~30까지의 요소를 ndarray에 담는다.
ndarray1 = np.arange(start=1, stop=31)
print(ndarray1)

print('=' * 50)

# 2. 2차원 위치 인덱싱(Location indexing)
# 2-1. 2차원 배열 axis 0은 4, axis 1은 5로 1~20 요소 중 15값 추출하기
ndarray1 = np.arange(1, 21)
ndarray2 = ndarray1.reshape((4,5))
print(ndarray2[2, 4])

print("=" * 50)

# 2-2. Dimension, axis 0은 5로 변경
ndarray2 = ndarray1.reshape((5, -1))
print(ndarray2)

print("=" * 50)

# 2-3. 2행의 4번째 숫자 출력 (Location indexing)
print(ndarray2[1,3])

print("=" * 50)

# 3. 불린 인덱싱 (Boolean indexing)
# 3-1. 1~100중 짝수만 출력
ndarray1 = np.arange(1, 101)
ndarray2 = ndarray1[ndarray1 % 2 == 0]
print(ndarray2)

print("=" * 50)

# 3-2. 3-1에서 구한 요소를 axis 0이 10인 2차원 배열로 변환 후 82~100까지 추출하기
ndarray2 = ndarray1.reshape((10, -1))
ndarray3 = ndarray2[8:]
print(ndarray3.flatten())

print("=" * 50)

# 3-3. 3-2에서 구한 요소 중 x:86 y:100 좌표 구하기
ndarray4 = ndarray3[[0, 1],[2, 4]] 
print(ndarray4)

print("=" * 50)

# 3-4. 불리언 인덱싱을 사용하여 각 요소중 1의 자리가 2인 수들만 추출하시오
ndarray1 = np.arange(1, 101)
ndarray2 = ndarray1[ndarray1 % 2 == 0]
cond = ndarray2 % 10 == 2
ndarray3 = ndarray2[cond]

print(ndarray3)

print("=" * 50)

# 3-5. 1~49 요소 중 2와 5의 공배수를 추출하세요.
ndarray1 = np.arange(start=1, stop=50)

cond1 = ndarray % 2 == 0
cond2 = ndarray % 5 == 0
cond3 = cond1 & cond2

ndarray2 = ndarray[cond3]
print(ndarray2)

print("=" * 50)

# 3-6. 3-5에서 추출한 공배수 중 20이상인 값만 추출하세요.
print(ndarray2[(ndarray2 >= 20)])

# %%
# 1. np.arange()를 사용하여 1부터 50까지의 정수를 포함하는 1차원 배열을 생성
ndarray1 = np.arange(1, 51)
print("=" * 30)
print(ndarray1)

# 2. 이 배열을 5x10의 2차원 배열로 변환
ndarray2 = ndarray1.reshape(5, 10)
print("=" * 30)
print(ndarray2)

# 3. 팬시 인덱싱을 사용하여 2차원 배열의 2, 4 행을 추출
fancyarray = ndarray2[[1, 3]]
print("=" * 30)
print(fancyarray)

# 4. 불린 인덱싱을 사용하여 2차원 배열에서 5의 배수만 추출
boolarray = ndarray2[ndarray2 % 5 == 0]
print("=" * 30)
print(boolarray)

# 5. 추출한 원소들의 합, 평균, 최소값, 최대값
sum_elements = np.sum(boolarray)
average_elements = np.average(boolarray)
min_element = np.min(boolarray)
max_element = np.max(boolarray)

print("===결과===")
print(sum_elements)
print(average_elements)
print(min_element)
print(max_element)

# %% [markdown]
# ### np.argsort() Task

# %%
import numpy as np
# 데이터를 분석하여, 각 수치별 오름차순 및 내림차순 후 이름을 출력하세요.
ndarray.ravel(): 2차원 넘파이 배열을 1차원 넘파이 배열로 변경(mutable)
ndarray.flatten(): 2차원 넘파이 배열을 1차원 넘파이 배열로 변경(immutable)

[[과일이름], [가격]], 가격별 내림차순
array1 = [['Mango', 'Apple', 'Pear', 'Pitch', 'Melon'], [1500, 1800, 2000, 2500, 8500]]
price = np.array(array1[1])
sort_indices = np.argsort(price)
print(price)

fruits = np.array(array1[0])

sorted_fruits = fruits[sort_indices[::-1]]
sorted_prices = price[sort_indices[::-1]]

print(sorted_fruits)
print(sorted_prices)


# [[이름], [나이], [학점]], 나이별 내림차순, 학점별 오름차순
array2 = [['둘리', '또치', '길동', '도너', '마이콜'], [7, 9, 40, 5, 20], ['C', 'A', 'B', 'F', 'D']]

print("===나이===")
age = np.array(array2[1])
sort_age_indices = np.argsort(age)
print(sort_age_indices)
students = np.array(array2[0])
sorted_students_age = students[sort_age_indices]
print(sorted_students_age)

print("===학점===")
score = np.array(array2[2])
sort_indices = np.argsort(score)
print(sort_indices[::-1])
students = np.array(array2[0])
sorted_students = students[sort_indices[::-1]]
print(sorted_students)

# [[국가이름], [GDP 성장률]], GDP 성장률별 오름차순
array3 = [['영국', '러시아', '남아프리카 공화국', '미국', '한국'], ['-0.6%', '0.3%', '1.2%', '1.4%', '1.7%']]
gdp = np.array(array3[1])
sort_indices = np.argsort(gdp)
print(sort_indices)
contry = np.array(array3[0])
sorted_contry = contry[sort_indices]
print(sorted_contry)
# Out:
# [0 1 2 3 4]
# ['영국' '러시아' '남아프리카 공화국' '미국' '한국']

# %%
# [[과일이름], [가격]], 가격별 내림차순
ndarray = np.array(array1)
print(ndarray)
fruit_name = ndarray[:1].flatten()
fruit_price = ndarray[1:2].flatten()
print(fruit_name, fruit_price)

fruit_name_sorted_desc = fruit_name[np.argsort(fruit_price)[::-1]]
print(fruit_name_sorted_desc)

# %%
# [[이름], [나이], [학점]], 나이별 내림차순, 학점별 오름차순
ndarray = np.array(array2)
print(ndarray)

# 나이별 내림차순
names = ndarray[:1].flatten()
ages = ndarray[1:2].flatten().astype(np.int32)
print(names, ages)

names_sorted_by_ages_desc = names[np.argsort(ages)[::-1]]
print(names_sorted_by_ages_desc)

# 학점별 오름차순
grades = ndarray[2:3].flatten()
names_sorted_by_grades = names[np.argsort(grades)]
print(names_sorted_by_grades)

# %%
# [[국가이름], [GDP 성장률]], GDP 성장률별 오름차순
ndarray = np.array(array3)
print(ndarray)

nations = ndarray[:1].flatten()
increase_ratings_of_GDP = []

increase_ratings_of_GDP_data = ndarray[1:2].flatten()

for i in increase_ratings_of_GDP_data:
    increase_ratings_of_GDP.append(i.replace('%', ''))

increase_ratings_of_GDP = np.array(increase_ratings_of_GDP, dtype=np.float32)
print(nations, increase_ratings_of_GDP)

nations_sorted_by_GDP = nations[np.argsort(increase_ratings_of_GDP)]
print(nations_sorted_by_GDP)

# %% [markdown]
# ### Linear Equation Task

# %%
# 다음 행렬을 내적하세요.

'''
A1      A2
1 2 3   7 8
4 5 6   9 10
        11 12
'''

A1 = np.array([[1, 2, 3], [4, 5, 6]])
A2 = np.array([[7, 8], [9, 10], [11, 12]])

result = np.dot(A1, A2)

print(result)
# Out:
# [[ 58  64]
#  [139 154]]

# %%
# 다음 연립방정식을 전치 행렬과 행렬 내적 
# 그리고 역행렬(np.linalg.inv())을 통해 해결하세요.

# k = [[k1], [k2]]
# A = [[x1, x2], [y1, y2]]
# w = [[w1], [w2]]

# k1 = x1w1 + x2w2
# k2 = y1w1 + y2w2
# k = Aw
# np.linalg.inv(A)*k = w * (np.linalg.inv(A)* A)
# x + 2y + 3z = 1
# x + 2y + z = 3
# x + 3z = 5

A = np.array([[1, 2, 3], [1, 2, 1], [1, 0, 3]])
k = np.array([[1, 3, 5]]).T
print(np.dot(np.linalg.inv(A), k))


print(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 16
#       1 # 다음 연립방정식을 전치 행렬과 행렬 내적
#       2 # 그리고 역행렬(np.linalg.inv())을 통해 해결하세요.
#       3
#    (...)
#      13 # x + 2y + z = 3
#      14 # x + 3z = 5
# ---> 16 A_inv = np.linalg.inv(A)
#      17 k = np.dot(A_inv, w)
#      19 A = np.array([[1,2,3],[1,2,1],[1,0,3]])
#
# NameError: name 'A' is not defined

# %%
# x + y = 10
# 2x - 3y = 10

# Aw = k

A = np.array([[1, 1], [2, -3]])
k = np.array([[10, 10]]).T

print(np.dot(np.linalg.inv(A), k))
